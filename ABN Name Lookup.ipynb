# %%
import urllib.request as req
from bs4 import BeautifulSoup

#Search parameters for ABRSearchByNameSimpleProtocol service
#Note, this service requires all parameters to be specified, even if you specify no query parameter
#The parameters specified below will search for an entity with  the name 'coles' with postcode '2250'
#In this case, unspecified search parameters all default to 'Y' 
#(i.e. will search for the legal & trading name 'coles' in all States and Territories
name = 'woolworths'
postcode = ''
legalName = ''
tradingName = ''
NSW = ''
SA = ''
ACT = ''
VIC = ''
WA = ''
NT = ''
QLD = ''
TAS = ''
authenticationGuid = '993d7e7d-f27f-40f4-97cf-2389214f814a' #Your GUID should go here

#Constructs the URL by inserting the search parameters specified above
#GETs the url (using urllib.request.urlopen)
conn = req.urlopen('http://abr.business.gov.au/abrxmlsearchRPC/AbrXmlSearch.asmx/' + 
                   'ABRSearchByNameSimpleProtocol?name=' + name + 
                   '&postcode=' + postcode + '&legalName=' + legalName + 
                   '&tradingName=' + tradingName + '&NSW=' + NSW + 
                   '&SA=' + SA + '&ACT=' + ACT + '&VIC=' +  VIC + 
                   '&WA=' + WA + '&NT=' + NT + '&QLD=' + QLD + 
                   '&TAS=' + TAS + '&authenticationGuid=' + authenticationGuid)

#XML is returned by the webservice
#Put returned xml into variable 'returnedXML' 
#Output xml string to file 'output.xml' and print to console
returnedXML = conn.read()
soup = BeautifulSoup(returnedXML, "lxml")
print(soup.prettify)
#f = open('output.xml', 'wb')
#f.write(returnedXML)
#f.close
# Out:
# <bound method Tag.prettify of <?xml version="1.0" encoding="utf-8"?><html><body><abrpayloadsearchresults xmlns="http://abr.business.gov.au/ABRXMLSearchRPC/literalTypes" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# <request>
# <namesearchrequest>
# <authenticationguid>993d7e7d-f27f-40f4-97cf-2389214f814a</authenticationguid>
# <name>woolworths</name>
# <filters>
# <nametype>
# <tradingname>Y</tradingname>
# <legalname>Y</legalname>
# </nametype>
# <postcode></postcode>
# <statecode>
# <qld>Y</qld>
# <nt>Y</nt>
# <sa>Y</sa>
# <wa>Y</wa>
# <vic>Y</vic>
# <act>Y</act>
# <tas>Y</tas>
# <nsw>Y</nsw>
# </statecode>
# </filters>
# </namesearchrequest>
# </request>
# <response>
# <usagestatement>The Registrar of the ABR monitors the quality of the information available on this website and updates the information regularly. However, neither the Registrar of the ABR nor the Commonwealth guarantee that the information available through this service (including search results) is accurate, up to date, complete or accept any liability arising from the use of or reliance upon this site.</usagestatement>
# <dateregisterlastupdated>2017-10-17</dateregisterlastupdated>
# <datetimeretrieved>2017-10-17T09:40:44.8230078+11:00</datetimeretrieved>
# <searchresultslist>
# <numberofrecords>124</numberofrecords>
# <exceedsmaximum>N</exceedsmaximum>
# <searchresultsrecord>
# <abn>
# <identifiervalue>97342304522</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>THE WOOLWORTHS</organisationname>
# <score>100</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>SA</statecode>
# <postcode>5069</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>88000014675</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS LTD</organisationname>
# <score>100</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2153</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>50095010549</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>CALTEX WOOLWORTHS</organisationname>
# <score>97</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2042</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>83009671149</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS (PUBLISHING) PTY LTD</organisationname>
# <score>97</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>62000034819</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS (Q'LAND) PTY LIMITED</organisationname>
# <score>97</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>34007873118</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTH
identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>WOOLWORTH TOURS</organisationname>
# <score>90</score>
# <iscurrentindicator>N</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>TAS</statecode>
# <postcode>7330</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>51609665152</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>MP BAKEWELL WOOLWORTHS SHOP 9</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>NT</statecode>
# <postcode>0832</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>85630284470</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>THE TEXT MEDIA GROUP LTD &amp; WOOLWORTHS (PUBLISHING) PTY LTD</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2010</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>17890658762</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The Trustee for INDUSTRIAL EQUITY LIMITED AND WOOLWORTHS LTD SUBVENTION AGREEMENT</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>49473700930</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The Trustee for NAKED ORGANICS (WOOLWORTHS) UNIT TRUST</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3011</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>40367353273</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The Trustee for WOOLWORTHS EXECUTIVE MGT SHARE PLAN</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>50389459212</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The Trustee for WOOLWORTHS NON EXECUTIVE DIRECTORS SHARE PLAN</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>63000039252</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>WOOLWORTHS MARKETPLACE AT ALBANY CREEK</organisationname>
# <score>88</score>
# <iscurrentindicator>N</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>65570703351</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS MARYBOROUGH SOCIAL CLUB 2664</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>QLD</statecode>
# <postcode>4650</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>28514124841</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS PALMERSTON SHOPPING CENTRE PARTNERSHIP</organisationname>
# <score>88</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NT</statecode>
# <postcode>0828</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>67087651803</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORTHS SAFEWAY EMPLOYEES CREDIT CO-OPERATIVE LIMITED</organisationname>
# <score>88</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3170</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>88000014675</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>WOOLWORTHS SUPERMARKETS FREQUENT SHOPPER CLUB</organisationname>
# <score>88</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2153</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>91278972285</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>M LUCAS &amp; SONS NOMINEES PTY LTD WOOLWORTHS CAMPSIE PROPERTY</organisationname>
# <score>85</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2033</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>99670178534</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>M LUCAS &amp; SONS NOMINEES PTY LTD WOOLWORTHS FAIRFIELD HEIGHTS</organisationname>
# <score>85</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2033</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>48031430184</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>TerryWhite Chemmart Woolworths Shopping Centre Blackwood</organisationname>
# <score>85</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>SA</statecode>
# <postcode>5051</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>99670178534</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>M LUCAS &amp; SONS NOMINEES PTY LTD WOOLWORTHS FAIRFIELD HEIGHTS PROPERTY</organisationname>
# <score>82</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2033</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>67933198502</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>Wallworth</organisationname>
# <score>79</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2009</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>38468813178</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>MESKILL WOOLWORKS</organisationname>
# <score>77</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3444</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>25663902117</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <legalname>
# <fullname>JESSICA WALLWORTH</fullname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3919</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>39104966857</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>JORDAN WALLWORTH</fullname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3912</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>60664565540</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>LEIGH WALLWORTH</fullname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3781</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>67709612652</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>LYNETTE WALLWORTH</fullname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2505</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>70321858698</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <legalname>
# <fullname>STACEY WALLWORTH</fullname>
# <score>76</score>
# <iscurrentindicator>N</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3175</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>77073376256</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The Trustee for THE WELLWORTH TRUST</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>WA</statecode>
# <postcode>6056</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>37547212782</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>Vivian Wallworth</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3976</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>49119072847</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WELLWORTH AUSTRALIA PTY LTD</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3079</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>71059740457</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WELLWORTH HOMES PTY. LTD.</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3040</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>14134579730</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WELWORTH GLASS PTY LTD</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3125</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>96168690435</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WILLWORTH SPORTS PTY LTD</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>QLD</statecode>
# <postcode>4703</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>77150333654</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>Wellworth Finance</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>QLD</statecode>
# <postcode>4012</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>19113306620</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>Willworth Estate Pty Ltd</organisationname>
# <score>76</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3930</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>71095072209</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>23A WALWORTH AVENUE PTY. LTD.</organisationname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2104</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>96153078106</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>DENISE THERESE WALLWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2233</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>82506342738</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>EMMA JAYNE WALLWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3140</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>66308847354</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <legalname>
# <fullname>GLENN JEREMY WALWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2095</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>67709612652</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>L.M.WALLWORTH</organisationname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2505</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>60664565540</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <legalname>
# <fullname>LEIGH ANDREW WALLWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>N</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3781</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>67933198502</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <legalname>
# <fullname>TASMAN JAMES WALLWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2009</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>37547212782</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <legalname>
# <fullname>VIVIAN CLAIRE WALLWORTH</fullname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </legalname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3976</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>31608188432</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>VR WALLWORTH1 PTY LTD</organisationname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2042</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>39104966857</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>WALLWORTH REFRIGERATION &amp; AIR CONDITIONING</organisationname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3912</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>19003677245</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WELLWORTH CHINA INVESTMENTS LIMITED</organisationname>
# <score>73</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2015</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>62252988500</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <maintradingname>
# <organisationname>WILWORTH MAIL SERVICE</organisationname>
# <score>73</score>
# <iscurrentindicator>N</iscurrentindicator>
# </maintradingname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2168</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>82100868666</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WILWORTH MAIL SERVICES PTY. LTD.</organisationname>
# <score>73</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2168</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>37002248545</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>The trustee for Wellworth Plant Hire Trust</organisationname>
# <score>70</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>QLD</statecode>
# <postcode>4568</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>27139824981</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WELWORTHY PTY. LTD.</organisationname>
# <score>70</score>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>VIC</statecode>
# <postcode>3004</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>24086126310</identifiervalue>
# <identifierstatus>Active</identifierstatus>
# </abn>
# <businessname>
# <organisationname>WOOLWORLD</organisationname>
# <score>70</score>
# <iscurrentindicator>N</iscurrentindicator>
# </businessname>
# <mainbusinessphysicaladdress>
# <statecode>NSW</statecode>
# <postcode>2000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# <searchresultsrecord>
# <abn>
# <identifiervalue>43760653652</identifiervalue>
# <identifierstatus>Cancelled</identifierstatus>
# </abn>
# <mainname>
# <organisationname>WOOLWORLD</organisationname>
# <score>70</score>
# <iscurrentindicator>N</iscurrentindicator>
# </mainname>
# <mainbusinessphysicaladdress>
# <statecode>TAS</statecode>
# <postcode>7000</postcode>
# <iscurrentindicator>Y</iscurrentindicator>
# </mainbusinessphysicaladdress>
# </searchresultsrecord>
# </searchresultslist>
# </response>
# </abrpayloadsearchresults></body></html>>
